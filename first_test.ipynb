# %%
import pandas as pd

# %%
csv_path = './csv/200-csv'
tagged_path = './tagged'

# %%
pd.read_csv(csv_path + '/1.csv')
# Out:
#     Year                                     Title  \
# 0   1995                               Polio Water
# 1   1996                         New York Crossing
# 2   1997                                 Lawn Dogs
# 3   1999                                      Pups
# 4   1999                              Notting Hill
# 5   1999                           The Sixth Sense
# 6   2000                                  Paranoid
# 7   2000                             Skipped Parts
# 8   2000                           Frankie & Hazel
# 9   2001                        Lost and Delirious
# 10  2001                             Julie Johnson
# 11  2001                                      Tart
# 12  2002                   A Ring of Endless Light
# 13  2003                                    Octane
# 14  2006                            The Oh in Ohio
# 15  2007                          Closing the Ring
# 16  2007                              St Trinian's
# ...

# %%
pd.read_csv(tagged_path + '/200-tagged/1.tagged', sep='\t')
# Out:
#      row  col                       id          content           tokens  \
# 0     -1    0          fb:row.row.year             Year             year
# 1     -1    1         fb:row.row.title            Title            title
# 2     -1    2          fb:row.row.role             Role             role
# 3     -1    3         fb:row.row.notes            Notes            notes
# 4      0    0             fb:cell.1995             1995             1995
# ..   ...  ...                      ...              ...              ...
# 123   29    3             fb:cell.null              NaN              NaN
# 124   30    0             fb:cell.2013             2013             2013
# 125   30    1       fb:cell.gutsy_frog       Gutsy Frog       gutsy|frog
# 126   30    2        fb:cell.ms_monica       Ms. Monica       ms.|monica
# 127   30    3  fb:cell.television_film  Television film  television|film
#
#          lemmaTokens  posTags   nerTags nerValues  number        date  num2  \
# ...

# %%
pd.read_csv(tagged_path + '/data/training.tagged', sep='\t')
# Out:
#              id                                          utterance  \
# 0          nt-0  what was the last year where this team was a p...
# 1          nt-1  in what city did piotr's last 1st place finish...
# 2          nt-2              which team won previous to crettyard?
# 3          nt-3  how many more passengers flew to los angeles t...
# 4          nt-4  who was the opponent in the first game of the ...
# ...         ...                                                ...
# 14147  nt-14147                                  who came in last?
# 14148  nt-14148  which album has the highest number of sales bu...
# 14149  nt-14149           japan finished below how many countries?
# 14150  nt-14150  how many districts have a population density o...
# 14151  nt-14151                 what entrant has the most drivers?
#
#                    context               targetValue  \
# 0      csv/204-csv/590.csv                      2004
# ...
